# %% [markdown]
# # Preparing the Data
# This notebook contains the data preparation aspect of this project, defining key functions to use to extract the data from the required APIs

# %%
# Initialize notebook and define libraries
import pandas as pd
import requests
import json
from datetime import datetime
import pytz
import math
import numpy as np
import time
import os
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import recall_score

# %matplotlib inline
plt.style.use('fivethirtyeight')
sns.set_context("notebook")
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ## Repeated Functions
# These functions are utilized various time in the data processing phase

# %%
# Cooldown function to ensure maximum requests per minute for API is not exceeded
def cooldown(start_time, max_requests_per_minute = 39, cooldown_time = 60):
    
    elapsed_time = time.time() - start_time
    
    if elapsed_time < (cooldown_time / max_requests_per_minute):
        time.sleep(cooldown_time / max_requests_per_minute - elapsed_time)

        
# Formating function to format the API output       
def format_df(data, drop=None):
    
    df = pd.DataFrame(data[0]['history']).set_index('t')
    df.index = pd.to_datetime(df.index, unit='s')

    if drop is not None:
        df.drop(drop, axis=1, inplace=True)

    return df



# Get all function performs cummulative operations for all symbols in a category, takes a function as an input
def get_all(func, api_key):
    
    all_data = pd.DataFrame()
    symbols = get_all_symbols(api_key)

    for symbol in symbols:
        start_time = time.time()
        df = func(api_key, symbol)
        all_data = pd.concat([all_data, df], axis=1)
        cooldown(start_time)
        
    return all_data


# Interpolate data function interpolates missing data for missing days in the period from 2022-01-02 to 2023-12-02
def interpolate(data):
    
    reference_dates = pd.date_range(start='2022-01-02', end='2023-12-02', freq='D')
    data = data.reindex(reference_dates)
    data = data.interpolate(method='time')
    
    return data

# %% [markdown]
# ## Defining Time Limits for Project
# For this project we are focusing on the daily activity of each cryptocurrency token with time horizons between January 1, 2022 to January 1, 2024

# %%
# Define time intervals and define start and end dates for analysis
interval = 'daily'
start = int(time.mktime(time.strptime('2022-01-01 00:00:00', '%Y-%m-%d %H:%M:%S')))
end = int(time.mktime(time.strptime('2024-01-01 00:00:00', '%Y-%m-%d %H:%M:%S')))

# %% [markdown]
# ## API Key
# The API Key is required to extract the cryptocurrency data from the Coinalyze API. The URL to use for the JSON requests is below
#
# API DOCS: https://api.coinalyze.net/v1/doc/

# %%
# API key, which changes for each user
api_key = '86bcc4d5-757a-46ed-bb59-72dd3b510e26'

# %% [markdown]
# ## Crypto Token Symbols
# Main Suffixes:
#
# - USDT.6: USD tether trading on ".6" exchange
# - USDT_PERP.A:USD tether trading perpetually on ".A" exchange
# - Misc suffixes for coins trading on other platforms
#
# The coins we are interested in are the ones with USDT_PERP.A suffix. The get_all_symbols function defined below is utilzied to extract all the names of the available tokens on the Coinalyze API.

# %%
def get_all_symbols(api_key):

    url = 'https://api.coinalyze.net/v1/future-markets'
    params = {'api_key': api_key}
    
    # Perform the JSON request using the url for future markets and the API key
    response = requests.get(url, params=params)
    data = response.json()
    
    # Extract the values for each dictionary corresponding to the symbol key and convert to a list
    symbols = pd.Series([d['symbol'] for d in data])
    
    # Return only symbols that are trading in perpetual contract with ".A" exchange
    symbols = symbols[symbols.str.endswith('USDT_PERP.A')]
    
    # Filter out the following symbol
    symbols = symbols[~symbols.str.contains('BTCDOMUSDT')]
    
    symbols = symbols.reset_index(drop=True)

    return symbols

# %% [markdown]
# The process of extracting the data from the Coinalyze API is a very tedious process, as a maximum of 40 requests per minute can be made, and over 234 symbols are available. Therefore the following list "symbols" contains the symbols that have data for the entire time horizon, minimizing time spent waiting.

# %%
symbols_cv = ['RSRUSDT_PERP.A', 'DYDXUSDT_PERP.A', 'LTCUSDT_PERP.A', 'THETAUSDT_PERP.A', '1000SHIBUSDT_PERP.A', 'MASKUSDT_PERP.A', 'BTCUSDT_PERP.A', 'BALUSDT_PERP.A', 'BATUSDT_PERP.A', 'ROSEUSDT_PERP.A', 'CHRUSDT_PERP.A', 'EGLDUSDT_PERP.A', 'STMXUSDT_PERP.A', 'ZILUSDT_PERP.A', 'FLMUSDT_PERP.A', 'KNCUSDT_PERP.A', 'QTUMUSDT_PERP.A', 'TRXUSDT_PERP.A', 'MATICUSDT_PERP.A', 'BAKEUSDT_PERP.A', 'HBARUSDT_PERP.A', 'XEMUSDT_PERP.A', 'KLAYUSDT_PERP.A', 'XLMUSDT_PERP.A', 'SXPUSDT_PERP.A', 'BLZUSDT_PERP.A', 'PEOPLEUSDT_PERP.A', 'ETHUSDT_PERP.A', 'NEOUSDT_PERP.A', 'MANAUSDT_PERP.A', 'CELOUSDT_PERP.A', 'SUSHIUSDT_PERP.A', 'FTMUSDT_PERP.A', 'WAVESUSDT_PERP.A', 'AAVEUSDT_PERP.A', 'ICXUSDT_PERP.A', 'XRPUSDT_PERP.A', 'IOTXUSDT_PERP.A', 'AUDIOUSDT_PERP.A', 'RENUSDT_PERP.A', 'SANDUSDT_PERP.A', 'SFPUSDT_PERP.A', 'ANKRUSDT_PERP.A', '1000XECUSDT_PERP.A', 'UNIUSDT_PERP.A', 'ARPAUSDT_PERP.A', 'SNXUSDT_PERP.A', 'HOTUSDT_PERP.A', 'IOTAUSDT_PERP.A', 'NEARUSDT_PERP.A', 'ALICEUSDT_PERP.A', 'OGNUSDT_PERP.A', 'STORJUSDT_PERP.A', 'COMPUSDT_PERP.A', 'VETUSDT_PERP.A', 'ENJUSDT_PERP.A', 'AXSUSDT_PERP.A', 'BELUSDT_PERP.A', 'ONTUSDT_PERP.A', 'LPTUSDT_PERP.A', 'DASHUSDT_PERP.A', 'C98USDT_PERP.A', 'ETCUSDT_PERP.A', 'DENTUSDT_PERP.A', 'ZRXUSDT_PERP.A', 'KSMUSDT_PERP.A', 'RVNUSDT_PERP.A', 'CRVUSDT_PERP.A', 'LINKUSDT_PERP.A', 'IOSTUSDT_PERP.A', 'ATOMUSDT_PERP.A', 'REEFUSDT_PERP.A', 'SOLUSDT_PERP.A', 'SKLUSDT_PERP.A', 'ANTUSDT_PERP.A', 'OCEANUSDT_PERP.A', 'LINAUSDT_PERP.A', 'ADAUSDT_PERP.A', 'DGBUSDT_PERP.A', 'UNFIUSDT_PERP.A', 'YFIUSDT_PERP.A', 'ENSUSDT_PERP.A', 'ALPHAUSDT_PERP.A', 'CTSIUSDT_PERP.A', 'BNBUSDT_PERP.A', 'KAVAUSDT_PERP.A', 'LRCUSDT_PERP.A', '1INCHUSDT_PERP.A', 'LITUSDT_PERP.A', 'COTIUSDT_PERP.A', 'TRBUSDT_PERP.A', 'GALAUSDT_PERP.A', 'EOSUSDT_PERP.A', 'ATAUSDT_PERP.A', 'OMGUSDT_PERP.A', 'DOTUSDT_PERP.A', 'MTLUSDT_PERP.A', 'BANDUSDT_PERP.A', 'GRTUSDT_PERP.A', 'CELRUSDT_PERP.A', 'DEFIUSDT_PERP.A', 'CHZUSDT_PERP.A', 'AVAXUSDT_PERP.A', 'ARUSDT_PERP.A', 'ALGOUSDT_PERP.A', 'XMRUSDT_PERP.A', 'MKRUSDT_PERP.A', 'ONEUSDT_PERP.A', 'RLCUSDT_PERP.A', 'NKNUSDT_PERP.A', 'BCHUSDT_PERP.A', 'GTCUSDT_PERP.A', 'ZENUSDT_PERP.A', 'ZECUSDT_PERP.A', 'RUNEUSDT_PERP.A', 'XTZUSDT_PERP.A', 'CTKUSDT_PERP.A', 'DOGEUSDT_PERP.A', 'FILUSDT_PERP.A']

# %% [markdown]
# ## Close and Volume Data
# The following function creates a dataframe with a time series index spanning from early January 2022 to late December 2023. The function takes in the inputs of the API Key, the daily interval, the start and end periods, as well as the symbols defined above, normally get_all_symbols() would be used.
#
# Since there is a requests limit, the function ensures that the requests per minute limit is not exceeded. The function creates a dataframe for each coin that has the close and volume information for each day. Then all the dataframes are joined together to return all the data in one dataframe.

# %%
def get_symbol_close_volume(api_key, symbol = "BTCUSDT_PERP.A", threshold=700):
    
    # Coinalyze URL for the close and volume data
    url = 'https://api.coinalyze.net/v1/ohlcv-history'
    
    # Define parameters for the request, can be found on the API site
    params = {'api_key': api_key,"symbols": symbol,"interval":interval,"from":start,"to":end,
              "history": [{
                  "t": 0,   # Unix Timestamp in seconds
                  "o": 0,   # Open
                  "h": 0,   # High
                  "l": 0,   # Low
                  "c": 0,   # Close
                  "v": 0,   # Volume
                  "bv": 0,  # Base Volume
                  "tx": 0,  # Total trades
                  "btx": 0  # Buy Trades
              }]
             }
    
    # Perform the JSON request with the URL and parameters
    response = requests.get(url, params=params)
    data = response.json()
    
    # Columns to drop (see column names above)
    drop = ['o', 'h', 'l', 'bv', 'tx', 'btx']
    
    #print(f"Symbol: {symbol}, Data Points: {len(data[0]['history'])}")
    
    # Estalish a threshold limit of minimum days in analysis periods with data
    if len(data[0]['history']) >= threshold:
        df = format_df(data, drop)
        df.rename(columns={'c': f"{data[0]['symbol']}_close", 'v': f"{data[0]['symbol']}_volume"}, inplace=True)
        
        return df

# %%
# Create dataframe containing only the Bitcoin close and volume data
close_volume_btc = get_symbol_close_volume(api_key)

# View the dataframe
close_volume_btc.head()
# Out:
#             BTCUSDT_PERP.A_close  BTCUSDT_PERP.A_volume
# t
# 2022-01-02              47280.00          184794.653000
# 2022-01-03              46445.81          244781.473999
# 2022-01-04              45833.42          292139.742999
# 2022-01-05              43421.69          485460.771998
# 2022-01-06              43080.01          299507.786999

# %%
# Create a dataframe containing the data for all coins
close_volume_all = get_all(get_symbol_close_volume,api_key)

# %%
# View the dataframe
close_volume_all
# Out:
#             PEOPLEUSDT_PERP.A_close  PEOPLEUSDT_PERP.A_volume  \
# t
# 2022-01-02                  0.12081                 366228687
# 2022-01-03                  0.12359                1620448582
# 2022-01-04                  0.11922                 592464466
# 2022-01-05                  0.10148                1091596364
# 2022-01-06                  0.10189                1627929359
# ...                             ...                       ...
# 2023-12-01                  0.01242                 526097636
# 2023-12-02                  0.01291                 772333755
# 2023-12-03                  0.01284                 913860735
# 2023-12-04                  0.01359                3368519325
# 2023-12-05                  0.01547                4820639714
#
#             OMGUSDT_PERP.A_close  OMGUSDT_PERP.A_volume  BALUSDT_PERP.A_close  \
# t
# 2022-01-02                6.2810              7454170.5                19.593
# 2022-01-03                6.1890              8643863.6                19.154
# 2022-01-04                6.0250              7992392.2                19.314
# 2022-01-05                5.5630              9675976.9                17.529
# 2022-01-06                5.6440              9182662.0                17.671
# ...                          ...                    ...                   ...
# 2023-12-01                0.6438             10348808.5                 3.822
# 2023-12-02                0.6603              8017030.2                 3.947
# 2023-12-03                0.6514             10472159.6                 4.048
# 2023-12-04                0.6723             27653936.7                 4.346
# 2023-12-05                0.6792             15185166.6                 4.270
#
#             BALUSDT_PERP.A_volume  RENUSDT_PERP.A_close  \
# t
# 2022-01-02              2154143.0               0.56380
# 2022-01-03              1712422.2               0.58140
# 2022-01-04              1491750.5               0.57860
# 2022-01-05              1319813.0               0.51790
# 2022-01-06              1350058.6               0.51900
# ...                           ...                   ...
# 2023-12-01              1865168.5               0.06040
# 2023-12-02              1266611.3               0.06178
# 2023-12-03              1662038.5               0.06111
# 2023-12-04              5007642.2               0.06784
# 2023-12-05              4220776.9               0.06778
#
#             RENUSDT_PERP.A_volume  CRVUSDT_PERP.A_close  \
# t
# 2022-01-02               69983534                 6.038
# 2022-01-03              144762720                 6.507
# 2022-01-04               75248782                 6.077
# 2022-01-05               91429399                 5.394
# 2022-01-06               63385696                 5.398
# ...                           ...                   ...
# 2023-12-01              211717248                 0.572
# 2023-12-02              325850198                 0.610
# 2023-12-03              267312149                 0.604
# 2023-12-04             1243114590                 0.607
# 2023-12-05              930893984                 0.609
#
#             CRVUSDT_PERP.A_volume  ...  1000XECUSDT_PERP.A_close  \
# t                                  ...
# 2022-01-02           1.036064e+08  ...                   0.11298
# 2022-01-03           1.369175e+08  ...                   0.11641
# 2022-01-04           1.093639e+08  ...                   0.11271
# 2022-01-05           1.059897e+08  ...                   0.10421
# 2022-01-06           9.355741e+07  ...                   0.10317
# ...                           ...  ...                       ...
# 2023-12-01           6.693228e+07  ...                   0.02926
# 2023-12-02           8.012060e+07  ...                   0.03018
# 2023-12-03           6.181809e+07  ...                   0.03085
# 2023-12-04           1.205764e+08  ...                   0.03144
# 2023-12-05           9.434266e+07  ...                   0.03109
#
#             1000XECUSDT_PERP.A_volume  ENSUSDT_PERP.A_close  \
# t
# 2022-01-02                  145318525                41.085
# 2022-01-03                  321535079                39.300
# 2022-01-04                  145264202                38.666
# 2022-01-05                  153789159                33.780
# 2022-01-06                  107552156                33.171
# ...                               ...                   ...
# 2023-12-01                  121489288                 8.587
# 2023-12-02                  485892947                 8.977
# 2023-12-03                  479349859                 8.817
# 2023-12-04                  669522066                 9.233
# 2023-12-05                  273222034                 9.147
#
#             ENSUSDT_PERP.A_volume  KLAYUSDT_PERP.A_close  \
# t
# 2022-01-02               974072.9                 1.3920
# 2022-01-03               845290.1                 1.3991
# 2022-01-04              1268892.0                 1.4024
# 2022-01-05              2120905.6                 1.3459
# 2022-01-06              1549395.1                 1.3470
# ...                           ...                    ...
# 2023-12-01              1388433.0                 0.1907
# 2023-12-02              2718034.7                 0.1936
# 2023-12-03              1783621.9                 0.1980
# 2023-12-04              3562089.7                 0.2056
# 2023-12-05              1896018.1                 0.2095
#
#             KLAYUSDT_PERP.A_volume  ARPAUSDT_PERP.A_close  \
# t
# 2022-01-02            1.100433e+07                0.09996
# 2022-01-03            4.737673e+07                0.10030
# 2022-01-04            1.512157e+07                0.09913
# 2022-01-05            3.414819e+07                0.09138
# 2022-01-06            2.448704e+07                0.09215
# ...                            ...                    ...
# 2023-12-01            5.565839e+07                0.05065
# 2023-12-02            6.579686e+07                0.05144
# 2023-12-03            7.530923e+07                0.05108
# 2023-12-04            1.075502e+08                0.05118
# 2023-12-05            6.463632e+07                0.05274
#
#             ARPAUSDT_PERP.A_volume  ANTUSDT_PERP.A_close  \
# t
# 2022-01-02               161401473                13.054
# 2022-01-03               164729769                11.969
# 2022-01-04               228777805                11.048
# 2022-01-05               204856943                10.260
# 2022-01-06               137694411                10.855
# ...                            ...                   ...
# 2023-12-01               150709986                 5.301
# 2023-12-02               118965640                 5.496
# 2023-12-03               144404370                 5.591
# 2023-12-04               368412112                 5.739
# 2023-12-05               278039108                 5.795
#
#             ANTUSDT_PERP.A_volume
# t
# 2022-01-02           6.937153e+06
# 2022-01-03           9.752468e+06
# 2022-01-04           6.519602e+06
# 2022-01-05           7.712332e+06
# 2022-01-06           1.984296e+07
# ...                           ...
# 2023-12-01           9.929284e+05
# 2023-12-02           9.119628e+05
# 2023-12-03           9.850237e+05
# 2023-12-04           2.137553e+06
# 2023-12-05           1.802966e+06
#
# [703 rows x 238 columns]

# %%
# Save the data in a csv to be used in the model building notebook
close_volume_all.to_csv('close volume.csv')

# %% [markdown]
# ## Long-Short Ratio
# This function returns the long-short ratio for the Bitcoin crypto token. This function calls for the Bitcoin symbol directly from the API, and stores it in a dataframe with a time series index.
#
# Long-short ratio definition: represents the amount of a security available for short selling versus the amount actually borrowed and sold; high long-short ratio indicates positive investor expectations.
#
# From: https://www.investopedia.com

# %%
def get_symbol_lsr(api_key, symbol = "BTCUSDT_PERP.A", threshold=693):
    
    url = 'https://api.coinalyze.net/v1/long-short-ratio-history'
    
    params = {'api_key': api_key,"symbols": symbol,"interval":interval,"from":start,"to":end,
              "history": [{
                  "t": 0, # Unix Timestamp in seconds
                  "r": 0, # Ratio
                  "l": 0, # Long
                  "s": 0  # Short
              }]
             }
    
    response = requests.get(url, params=params)
    data = response.json()
    
    drop = ['l','s']
    
    #print(f"Symbol: {symbol}, Data Points: {len(data[0]['history'])}")
    
    # Convert the data into a DataFrame
    if len(data[0]['history']) >= threshold:
        
        df = format_df(data, drop)
        df.rename(columns={'r': f"{data[0]['symbol']}_ls_ratio"}, inplace=True)
        
        return interpolate(df)

# %%
# Call the function to create the Bitcoin long-short ratio DF
lsr_btc = get_symbol_lsr(api_key)

# View the dataframe
lsr_btc
# Out:
#             BTCUSDT_PERP.A_ls_ratio
# 2022-01-02                   2.8432
# 2022-01-03                   2.8911
# 2022-01-04                   4.3677
# 2022-01-05                   4.1680
# 2022-01-06                   3.7824
# ...                             ...
# 2023-11-28                   1.2046
# 2023-11-29                   0.6793
# 2023-11-30                   0.8077
# 2023-12-01                   0.9305
# 2023-12-02                   0.5929
#
# [700 rows x 1 columns]

# %%
lsr_all = get_all(get_symbol_lsr,api_key)

# %%
lsr_all
# Out:
#             PEOPLEUSDT_PERP.A_ls_ratio  OMGUSDT_PERP.A_ls_ratio  \
# 2022-01-02                      4.8754                   5.2112
# 2022-01-03                      5.5359                   4.6022
# 2022-01-04                      5.8213                   5.2696
# 2022-01-05                      7.6881                   5.6667
# 2022-01-06                      5.4851                   5.1958
# ...                                ...                      ...
# 2023-11-28                      3.0258                   3.4763
# 2023-11-29                      2.0321                   3.2974
# 2023-11-30                      2.3422                   3.5662
# 2023-12-01                      2.8476                   3.6104
# 2023-12-02                      2.8536                   3.6620
#
#             BALUSDT_PERP.A_ls_ratio  RENUSDT_PERP.A_ls_ratio  \
# 2022-01-02                   2.5174                   3.6339
# 2022-01-03                   1.7115                   3.5893
# 2022-01-04                   2.3693                   4.7904
# 2022-01-05                   2.6792                   4.5279
# 2022-01-06                   2.7341                   3.9727
# ...                             ...                      ...
# 2023-11-28                   3.4326                   2.7651
# 2023-11-29                   3.3630                   2.8476
# 2023-11-30                   3.1824                   2.8491
# 2023-12-01                   3.3668                   3.5228
# 2023-12-02                   1.5445                   2.9308
#
#             CRVUSDT_PERP.A_ls_ratio  STORJUSDT_PERP.A_ls_ratio  \
# 2022-01-02                   1.1758                     3.2337
# 2022-01-03                   1.9886                     2.9078
# 2022-01-04                   1.5265                     3.8193
# 2022-01-05                   2.1496                     4.1813
# 2022-01-06                   3.3122                     4.0125
# ...                             ...                        ...
# 2023-11-28                   3.6860                     0.9697
# 2023-11-29                   3.4783                     0.8443
# 2023-11-30                   3.6468                     1.0296
# 2023-12-01                   3.3975                     1.0024
# 2023-12-02                   3.6664                     1.0133
#
#             RLCUSDT_PERP.A_ls_ratio  SXPUSDT_PERP.A_ls_ratio  \
# 2022-01-02                   2.5026                   1.1478
# 2022-01-03                   2.7793                   1.8121
# 2022-01-04                   4.0968                   3.2644
# 2022-01-05                   3.3066                   3.9480
# 2022-01-06                   3.6468                   3.5809
# ...                             ...                      ...
# 2023-11-28                   2.1546                   2.3400
# 2023-11-29                   1.7762                   2.2982
# 2023-11-30                   1.6738                   2.1939
# 2023-12-01                   2.0826                   2.9417
# 2023-12-02                   1.9464                   2.7341
#
#             KAVAUSDT_PERP.A_ls_ratio  RSRUSDT_PERP.A_ls_ratio  ...  \
# 2022-01-02                    0.9324                   3.7733  ...
# 2022-01-03                    2.5174                   3.6882  ...
# 2022-01-04                    2.1114                   3.8333  ...
# 2022-01-05                    1.2795                   3.9628  ...
# 2022-01-06                    3.0967                   4.7241  ...
# ...                              ...                      ...  ...
# 2023-11-28                    3.9727                   2.4002  ...
# 2023-11-29                    3.4643                   2.4990  ...
# 2023-11-30                    2.9185                   2.3223  ...
# 2023-12-01                    2.9841                   1.8760  ...
# 2023-12-02                    3.2535                   1.9300  ...
#
#             COTIUSDT_PERP.A_ls_ratio  DENTUSDT_PERP.A_ls_ratio  \
# 2022-01-02                    3.7778                    4.7537
# 2022-01-03                    4.3967                    5.1958
# 2022-01-04                    4.3792                    4.3505
# 2022-01-05                    5.2933                    4.8241
# 2022-01-06                    4.5218                    4.8241
# ...                              ...                       ...
# 2023-11-28                    2.0157                    2.0441
# 2023-11-29                    2.1606                    1.7716
# 2023-11-30                    1.8019                    1.8952
# 2023-12-01                    1.9949                    1.9922
# 2023-12-02                    2.1427                    1.8571
#
#             NKNUSDT_PERP.A_ls_ratio  IOTXUSDT_PERP.A_ls_ratio  \
# 2022-01-02                   3.4072                    3.7259
# 2022-01-03                   3.4863                    4.2466
# 2022-01-04                   4.4259                    6.2993
# 2022-01-05                   4.2165                    5.9204
# 2022-01-06                   4.5127                    5.1996
# ...                             ...                       ...
# 2023-11-28                   2.1666                    2.8095
# 2023-11-29                   1.9762                    2.4483
# 2023-11-30                   2.1496                    2.0012
# 2023-12-01                   2.0618                    1.9197
# 2023-12-02                   2.1211                    2.0516
#
#             CTSIUSDT_PERP.A_ls_ratio  1000XECUSDT_PERP.A_ls_ratio  \
# 2022-01-02                    3.0371                       7.6281
# 2022-01-03                    3.0967                       6.1480
# 2022-01-04                    3.2499                       5.4144
# 2022-01-05                    3.0225                       6.3584
# 2022-01-06                    3.6948                       6.3475
# ...                              ...                          ...
# 2023-11-28                    2.1279                       2.7495
# 2023-11-29                    2.1928                       3.0339
# 2023-11-30                    2.1878                       2.9293
# 2023-12-01                    2.3864                       3.3764
# 2023-12-02                    2.4317                       2.2626
#
#             ENSUSDT_PERP.A_ls_ratio  KLAYUSDT_PERP.A_ls_ratio  \
# 2022-01-02                   5.5833                    1.5349
# 2022-01-03                   5.3694                    1.6096
# 2022-01-04                   6.0771                    1.7078
# 2022-01-05                   6.1174                    1.9638
# 2022-01-06                   4.1706                    1.6048
# ...                             ...                       ...
# 2023-11-28                   2.2031                    1.1195
# 2023-11-29                   1.8257                    1.3624
# 2023-11-30                   2.7064                    1.3663
# 2023-12-01                   3.4623                    1.8466
# 2023-12-02                   2.9920                    2.3167
#
#             ARPAUSDT_PERP.A_ls_ratio  ANTUSDT_PERP.A_ls_ratio
# 2022-01-02                    5.2657                   0.9260
# 2022-01-03                    5.2150                   0.7224
# 2022-01-04                    5.0060                   1.8547
# 2022-01-05                    5.7385                   2.5920
# 2022-01-06                    5.7159                   3.2589
# ...                              ...                      ...
# 2023-11-28                    2.4400                   1.6048
# 2023-11-29                    2.6697                   1.6103
# 2023-11-30                    2.6805                   1.8377
# 2023-12-01                    2.9651                   1.7352
# 2023-12-02                    2.9698                   1.5549
#
# [700 rows x 119 columns]

# %%
# Save the data in a csv to be used in the model building notebook
lsr_all.to_csv('long short.csv')

# %% [markdown]
# ## Liquidations
#
#
# Short liquidation definition: the liquidation margin is equal to what the trader would owe to purchase the security.
#
# Long liquidation definition: the liquidation margin is equal to what the investor or trader would retain if the position were closed.
#
# From: https://www.investopedia.com

# %%
def get_symbol_liquidations(api_key, symbol = "BTCUSDT_PERP.A", threshold=696):
    
    url = 'https://api.coinalyze.net/v1/liquidation-history'
    
    params = {'api_key': api_key,"symbols": symbol,"interval":interval,"from":start,"to":end,
              #"convert_to_usd":'true',
              "history": [{
                  "t": 0, # Unix Timestamp in seconds
                  "l": 0, # Long liquidation
                  "s": 0  # Short liquidation
              }]
             }
    
    response = requests.get(url, params=params)
    data = response.json()
    
    print(f"Symbol: {symbol}, Data Points: {len(data[0]['history'])}")
    
    if len(data[0]['history'])>=threshold:
        df = format_df(data)
        df = df.rename(columns = {'l':'{}_longliq'.format(data[0]['symbol']),'s':'{}_shortliq'.format(data[0]['symbol'])})
    
        return interpolate(df)

# %%
liq_btc = get_symbol_liquidations(api_key)

liq_btc
# Out:
# Symbol: BTCUSDT_PERP.A, Data Points: 703
#             BTCUSDT_PERP.A_longliq  BTCUSDT_PERP.A_shortliq
# 2022-01-02                 114.778                   79.263
# 2022-01-03                 174.321                   69.337
# 2022-01-04                 385.271                  109.397
# 2022-01-05                 507.792                  182.757
# 2022-01-06                 120.827                  118.182
# ...                            ...                      ...
# 2023-11-28                  85.946                  198.702
# 2023-11-29                  87.249                   88.287
# 2023-11-30                  48.229                   47.969
# 2023-12-01                  51.462                  151.664
# 2023-12-02                  27.756                  124.160
#
# [700 rows x 2 columns]

# %%
liq_all = get_all(get_symbol_liquidations,api_key)
# Out:
# Symbol: NMRUSDT_PERP.A, Data Points: 158
# Symbol: BIGTIMEUSDT_PERP.A, Data Points: 55
# Symbol: POWRUSDT_PERP.A, Data Points: 40
# Symbol: MAVUSDT_PERP.A, Data Points: 159
# Symbol: AGLDUSDT_PERP.A, Data Points: 128
# Symbol: CYBERUSDT_PERP.A, Data Points: 107
# Symbol: ARKUSDT_PERP.A, Data Points: 78
# Symbol: WLDUSDT_PERP.A, Data Points: 135
# Symbol: PENDLEUSDT_PERP.A, Data Points: 130
# Symbol: ARKMUSDT_PERP.A, Data Points: 131
# Symbol: FRONTUSDT_PERP.A, Data Points: 75
# Symbol: BONDUSDT_PERP.A, Data Points: 52
# Symbol: MDTUSDT_PERP.A, Data Points: 156
# Symbol: SEIUSDT_PERP.A, Data Points: 110
# Symbol: XVGUSDT_PERP.A, Data Points: 154
# Symbol: BNTUSDT_PERP.A, Data Points: 110
# Symbol: YGGUSDT_PERP.A, Data Points: 123
# Symbol: DODOXUSDT_PERP.A, Data Points: 118
# Symbol: OXTUSDT_PERP.A, Data Points: 113
# Symbol: MINAUSDT_PERP.A, Data Points: 294
# Symbol: PEOPLEUSDT_PERP.A, Data Points: 702
# Symbol: RIFUSDT_PERP.A, Data Points: 46
# Symbol: ASTRUSDT_PERP.A, Data Points: 285
# Symbol: XVSUSDT_PERP.A, Data Points: 225
# Symbol: MAGICUSDT_PERP.A, Data Points: 314
# Symbol: TUSDT_PERP.A, Data Points: 300
# Symbol: FETUSDT_PERP.A, Data Points: 322
# Symbol: HIGHUSDT_PERP.A, Data Points: 301
# Symbol: RNDRUSDT_PERP.A, Data Points: 306
# Symbol: FXSUSDT_PERP.A, Data Points: 317
# Symbol: CFXUSDT_PERP.A, Data Points: 289
# Symbol: IDEXUSDT_PERP.A, Data Points: 204
# Symbol: SNTUSDT_PERP.A, Data Points: 34
# Symbol: USDCUSDT_PERP.A, Data Points: 131
# Symbol: ETHWUSDT_PERP.A, Data Points: 8
# Symbol: SUIUSDT_PERP.A, Data Points: 217
# Symbol: OMGUSDT_PERP.A, Data Points: 695
# Symbol: BALUSDT_PERP.A, Data Points: 671
# Symbol: RENUSDT_PERP.A, Data Points: 697
# Symbol: STXUSDT_PERP.A, Data Points: 286
# Symbol: CRVUSDT_PERP.A, Data Points: 699
# Symbol: APEUSDT_PERP.A, Data Points: 629
# Symbol: STORJUSDT_PERP.A, Data Points: 696
# Symbol: RLCUSDT_PERP.A, Data Points: 703
# Symbol: SXPUSDT_PERP.A, Data Points: 697
# Symbol: KAVAUSDT_PERP.A, Data Points: 701
# Symbol: RSRUSDT_PERP.A, Data Points: 703
# Symbol: MTLUSDT_PERP.A, Data Points: 700
# Symbol: DOGEUSDT_PERP.A, Data Points: 703
# Symbol: BANDUSDT_PERP.A, Data Points: 694
# Symbol: WAVESUSDT_PERP.A, Data Points: 703
# Symbol: KSMUSDT_PERP.A, Data Points: 691
# Symbol: WOOUSDT_PERP.A, Data Points: 600
# Symbol: DUSKUSDT_PERP.A, Data Points: 691
# Symbol: AGIXUSDT_PERP.A, Data Points: 292
# Symbol: PHBUSDT_PERP.A, Data Points: 289
# Symbol: CAKEUSDT_PERP.A, Data Points: 34
# Symbol: FOOTBALLUSDT_PERP.A, Data Points: 437
# Symbol: JASMYUSDT_PERP.A, Data Points: 589
# Symbol: STRAXUSDT_PERP.A, Data Points: 56
# Symbol: ACHUSDT_PERP.A, Data Points: 285
# Symbol: BNXUSDT_PERP.A, Data Points: 598
# Symbol: ALGOUSDT_PERP.A, Data Points: 699
# Symbol: MATICUSDT_PERP.A, Data Points: 702
# Symbol: KNCUSDT_PERP.A, Data Points: 689
# Symbol: ZILUSDT_PERP.A, Data Points: 695
# Symbol: BLZUSDT_PERP.A, Data Points: 695
# Symbol: NEARUSDT_PERP.A, Data Points: 700
# Symbol: AVAXUSDT_PERP.A, Data Points: 701
# Symbol: MKRUSDT_PERP.A, Data Points: 700
# Symbol: SNXUSDT_PERP.A, Data Points: 698
# Symbol: ENJUSDT_PERP.A, Data Points: 691
# Symbol: ZRXUSDT_PERP.A, Data Points: 690
# Symbol: FLMUSDT_PERP.A, Data Points: 691
# Symbol: FTMUSDT_PERP.A, Data Points: 700
# Symbol: OPUSDT_PERP.A, Data Points: 553
# Symbol: UNIUSDT_PERP.A, Data Points: 699
# Symbol: SKLUSDT_PERP.A, Data Points: 689
# Symbol: TRBUSDT_PERP.A, Data Points: 696
# Symbol: TRXUSDT_PERP.A, Data Points: 703
# Symbol: BNBUSDT_PERP.A, Data Points: 703
# Symbol: XRPUSDT_PERP.A, Data Points: 703
# Symbol: NEOUSDT_PERP.A, Data Points: 697
# Symbol: EOSUSDT_PERP.A, Data Points: 703
# Symbol: ETCUSDT_PERP.A, Data Points: 702
# Symbol: BTCUSDT_PERP.A, Data Points: 703
# Symbol: LTCUSDT_PERP.A, Data Points: 702
# Symbol: XLMUSDT_PERP.A, Data Points: 697
# Symbol: LINKUSDT_PERP.A, Data Points: 703
# Symbol: ETHUSDT_PERP.A, Data Points: 703
# Symbol: BCHUSDT_PERP.A, Data Points: 702
# Symbol: ADAUSDT_PERP.A, Data Points: 703
# Symbol: XMRUSDT_PERP.A, Data Points: 696
# Symbol: DASHUSDT_PERP.A, Data Points: 694
# Symbol: ZECUSDT_PERP.A, Data Points: 690
# Symbol: ONTUSDT_PERP.A, Data Points: 692
# Symbol: ATOMUSDT_PERP.A, Data Points: 703
# Symbol: XTZUSDT_PERP.A, Data Points: 675
# Symbol: IOTAUSDT_PERP.A, Data Points: 682
# Symbol: BATUSDT_PERP.A, Data Points: 682
# Symbol: VETUSDT_PERP.A, Data Points: 699
# Symbol: QTUMUSDT_PERP.A, Data Points: 682
# Symbol: IOSTUSDT_PERP.A, Data Points: 684
# Symbol: THETAUSDT_PERP.A, Data Points: 697
# Symbol: AUDIOUSDT_PERP.A, Data Points: 690
# Symbol: SUSHIUSDT_PERP.A, Data Points: 699
# Symbol: COMPUSDT_PERP.A, Data Points: 700
# Symbol: RUNEUSDT_PERP.A, Data Points: 697
# Symbol: DOTUSDT_PERP.A, Data Points: 703
# Symbol: FILUSDT_PERP.A, Data Points: 701
# Symbol: AAVEUSDT_PERP.A, Data Points: 696
# Symbol: UNFIUSDT_PERP.A, Data Points: 699
# Symbol: GRTUSDT_PERP.A, Data Points: 697
# Symbol: DEFIUSDT_PERP.A, Data Points: 631
# Symbol: GTCUSDT_PERP.A, Data Points: 697
# Symbol: YFIUSDT_PERP.A, Data Points: 693
# Symbol: FLOWUSDT_PERP.A, Data Points: 647
# Symbol: LRCUSDT_PERP.A, Data Points: 677
# Symbol: SOLUSDT_PERP.A, Data Points: 703
# Symbol: EGLDUSDT_PERP.A, Data Points: 694
# Symbol: ICXUSDT_PERP.A, Data Points: 683
# Symbol: IMXUSDT_PERP.A, Data Points: 653
# Symbol: OCEANUSDT_PERP.A, Data Points: 701
# Symbol: ROSEUSDT_PERP.A, Data Points: 691
# Symbol: CKBUSDT_PERP.A, Data Points: 265
# Symbol: OGNUSDT_PERP.A, Data Points: 693
# Symbol: BELUSDT_PERP.A, Data Points: 696
# Symbol: CTKUSDT_PERP.A, Data Points: 683
# Symbol: AXSUSDT_PERP.A, Data Points: 701
# Symbol: SPELLUSDT_PERP.A, Data Points: 449
# Symbol: MASKUSDT_PERP.A, Data Points: 701
# Symbol: ALPHAUSDT_PERP.A, Data Points: 699
# Symbol: ZENUSDT_PERP.A, Data Points: 684
# Symbol: ORBSUSDT_PERP.A, Data Points: 50
# Symbol: LDOUSDT_PERP.A, Data Points: 438
# Symbol: BAKEUSDT_PERP.A, Data Points: 695
# Symbol: CVXUSDT_PERP.A, Data Points: 416
# Symbol: 1INCHUSDT_PERP.A, Data Points: 696
# Symbol: LINAUSDT_PERP.A, Data Points: 701
# Symbol: TRUUSDT_PERP.A, Data Points: 271
# Symbol: CELOUSDT_PERP.A, Data Points: 695
# Symbol: 1000LUNCUSDT_PERP.A, Data Points: 451
# Symbol: GALAUSDT_PERP.A, Data Points: 703
# Symbol: PERPUSDT_PERP.A, Data Points: 262
# Symbol: CELRUSDT_PERP.A, Data Points: 697
# Symbol: GMXUSDT_PERP.A, Data Points: 291
# Symbol: 1000PEPEUSDT_PERP.A, Data Points: 215
# Symbol: DGBUSDT_PERP.A, Data Points: 673
# Symbol: REEFUSDT_PERP.A, Data Points: 692
# Symbol: ANKRUSDT_PERP.A, Data Points: 690
# Symbol: CHZUSDT_PERP.A, Data Points: 696
# Symbol: LPTUSDT_PERP.A, Data Points: 681
# Symbol: BLURUSDT_PERP.A, Data Points: 219
# Symbol: ALICEUSDT_PERP.A, Data Points: 696
# Symbol: 1000SHIBUSDT_PERP.A, Data Points: 703
# Symbol: SANDUSDT_PERP.A, Data Points: 701
# Symbol: RVNUSDT_PERP.A, Data Points: 674
# Symbol: GMTUSDT_PERP.A, Data Points: 629
# Symbol: EDUUSDT_PERP.A, Data Points: 219
# Symbol: SFPUSDT_PERP.A, Data Points: 694
# Symbol: LITUSDT_PERP.A, Data Points: 698
# Symbol: IDUSDT_PERP.A, Data Points: 257
# Symbol: XEMUSDT_PERP.A, Data Points: 679
# Symbol: ATAUSDT_PERP.A, Data Points: 693
# Symbol: HOTUSDT_PERP.A, Data Points: 694
# Symbol: STMXUSDT_PERP.A, Data Points: 682
# Symbol: C98USDT_PERP.A, Data Points: 701
# Symbol: ARUSDT_PERP.A, Data Points: 684
# Symbol: MANAUSDT_PERP.A, Data Points: 701
# Symbol: ONEUSDT_PERP.A, Data Points: 687
# Symbol: HBARUSDT_PERP.A, Data Points: 696
# Symbol: CHRUSDT_PERP.A, Data Points: 693
# Symbol: ARBUSDT_PERP.A, Data Points: 258
# Symbol: DYDXUSDT_PERP.A, Data Points: 703
# Symbol: SSVUSDT_PERP.A, Data Points: 278
# Symbol: KEYUSDT_PERP.A, Data Points: 188
# Symbol: COTIUSDT_PERP.A, Data Points: 697
# Symbol: DENTUSDT_PERP.A, Data Points: 695
# Symbol: COMBOUSDT_PERP.A, Data Points: 183
# Symbol: NKNUSDT_PERP.A, Data Points: 690
# Symbol: IOTXUSDT_PERP.A, Data Points: 667
# Symbol: CTSIUSDT_PERP.A, Data Points: 686
# Symbol: 1000XECUSDT_PERP.A, Data Points: 679
# Symbol: ENSUSDT_PERP.A, Data Points: 682
# Symbol: STPTUSDT_PERP.A, Data Points: 47
# Symbol: LQTYUSDT_PERP.A, Data Points: 270
# Symbol: KLAYUSDT_PERP.A, Data Points: 670
# Symbol: ARPAUSDT_PERP.A, Data Points: 685
# Symbol: JOEUSDT_PERP.A, Data Points: 250
# Symbol: WAXPUSDT_PERP.A, Data Points: 49
# Symbol: LOOMUSDT_PERP.A, Data Points: 56
# Symbol: RDNTUSDT_PERP.A, Data Points: 241
# Symbol: NTRNUSDT_PERP.A, Data Points: 22
# Symbol: LUNA2USDT_PERP.A, Data Points: 448
# Symbol: HFTUSDT_PERP.A, Data Points: 237
# Symbol: AMBUSDT_PERP.A, Data Points: 241
# Symbol: LEVERUSDT_PERP.A, Data Points: 244
# Symbol: TLMUSDT_PERP.A, Data Points: 396
# Symbol: HOOKUSDT_PERP.A, Data Points: 314
# Symbol: QNTUSDT_PERP.A, Data Points: 390
# Symbol: ANTUSDT_PERP.A, Data Points: 695
# Symbol: API3USDT_PERP.A, Data Points: 641
# Symbol: STGUSDT_PERP.A, Data Points: 460
# Symbol: INJUSDT_PERP.A, Data Points: 470
# Symbol: MBLUSDT_PERP.A, Data Points: 22
# Symbol: GALUSDT_PERP.A, Data Points: 573
# Symbol: APTUSDT_PERP.A, Data Points: 413
# Symbol: RADUSDT_PERP.A, Data Points: 198
# Symbol: UMAUSDT_PERP.A, Data Points: 191
# Symbol: BLUEBIRDUSDT_PERP.A, Data Points: 304
# Symbol: DARUSDT_PERP.A, Data Points: 562
# Symbol: ICPUSDT_PERP.A, Data Points: 587
# Symbol: KASUSDT_PERP.A, Data Points: 19
# Symbol: MEMEUSDT_PERP.A, Data Points: 33
# Symbol: HIFIUSDT_PERP.A, Data Points: 81
# Symbol: GLMRUSDT_PERP.A, Data Points: 71
# Symbol: BICOUSDT_PERP.A, Data Points: 69
# Symbol: TWTUSDT_PERP.A, Data Points: 33
# Symbol: TOKENUSDT_PERP.A, Data Points: 33
# Symbol: BSVUSDT_PERP.A, Data Points: 47
# Symbol: POLYXUSDT_PERP.A, Data Points: 42
# Symbol: GASUSDT_PERP.A, Data Points: 42
# Symbol: SLPUSDT_PERP.A, Data Points: 36
# Symbol: TIAUSDT_PERP.A, Data Points: 36
# Symbol: ORDIUSDT_PERP.A, Data Points: 29
# Symbol: STEEMUSDT_PERP.A, Data Points: 27
# Symbol: BADGERUSDT_PERP.A, Data Points: 27
# Symbol: ILVUSDT_PERP.A, Data Points: 26
# Symbol: SUPERUSDT_PERP.A, Data Points: 10
# Symbol: USTCUSDT_PERP.A, Data Points: 9
# Symbol: ONGUSDT_PERP.A, Data Points: 9
# Symbol: BEAMXUSDT_PERP.A, Data Points: 14
# Symbol: 1000BONKUSDT_PERP.A, Data Points: 14
# Symbol: PYTHUSDT_PERP.A, Data Points: 14

# %%
liq_all
# Out:
#             PEOPLEUSDT_PERP.A_longliq  PEOPLEUSDT_PERP.A_shortliq  \
# 2022-01-02                   438865.0                     59767.0
# 2022-01-03                  2109983.0                    974617.0
# 2022-01-04                   578912.0                    102480.0
# 2022-01-05                  5147538.0                    458971.0
# 2022-01-06                  1382699.0                   1372846.0
# ...                               ...                         ...
# 2023-11-28                  5335868.0                    405770.0
# 2023-11-29                   583670.0                    955866.0
# 2023-11-30                   679953.0                     39825.0
# 2023-12-01                    33936.0                    161156.0
# 2023-12-02                   177703.0                    306498.0
#
#             RENUSDT_PERP.A_longliq  RENUSDT_PERP.A_shortliq  \
# 2022-01-02                 15226.0                  39673.0
# 2022-01-03                279242.0                 134105.0
# 2022-01-04                 88626.0                  26938.0
# 2022-01-05               1065753.0                  38093.0
# 2022-01-06                 80025.0                  22704.0
# ...                            ...                      ...
# 2023-11-28                275800.0                  56843.0
# 2023-11-29                575287.0                  50670.0
# 2023-11-30                209877.0                   2492.0
# 2023-12-01                131033.0                  28477.0
# 2023-12-02                570548.0                  46127.0
#
#             CRVUSDT_PERP.A_longliq  CRVUSDT_PERP.A_shortliq  \
# 2022-01-02                195064.4                 143533.8
# 2022-01-03                210800.7                 259412.7
# 2022-01-04                198043.0                  50376.3
# 2022-01-05                527518.7                  71815.9
# 2022-01-06                118396.4                  73880.6
# ...                            ...                      ...
# 2023-11-28                  1434.6                     52.7
# 2023-11-29                  3749.2                      9.9
# 2023-11-30                  8726.2                      9.4
# 2023-12-01                  5068.7                   8245.8
# 2023-12-02                  2178.6                  79976.6
#
#             STORJUSDT_PERP.A_longliq  STORJUSDT_PERP.A_shortliq  \
# 2022-01-02                   29917.0                    21160.0
# 2022-01-03                   41807.0                     1551.0
# 2022-01-04                   23616.0                     3004.0
# 2022-01-05                  239899.0                     4017.0
# 2022-01-06                   21597.0                     7564.0
# ...                              ...                        ...
# 2023-11-28                  112033.0                    45837.0
# 2023-11-29                   16308.0                     2305.0
# 2023-11-30                    2931.0                     2209.0
# 2023-12-01                    3839.0                    18519.0
# 2023-12-02                    1299.0                    39841.0
#
#             RLCUSDT_PERP.A_longliq  RLCUSDT_PERP.A_shortliq  ...  \
# 2022-01-02                  3693.7                   2303.0  ...
# 2022-01-03                 25650.7                    356.9  ...
# 2022-01-04                 28555.9                  12089.4  ...
# 2022-01-05                 86365.0                   8362.9  ...
# 2022-01-06                  8362.6                    487.3  ...
# ...                            ...                      ...  ...
# 2023-11-28                  2761.1                     73.8  ...
# 2023-11-29                   787.3                   1816.8  ...
# 2023-11-30                  8186.8                   1815.8  ...
# 2023-12-01                  1306.8                     29.1  ...
# 2023-12-02                  6098.5                   7497.1  ...
#
#             C98USDT_PERP.A_longliq  C98USDT_PERP.A_shortliq  \
# 2022-01-02                  5853.0                   1889.0
# 2022-01-03                 40169.0                     77.0
# 2022-01-04                 14214.0                  20723.0
# 2022-01-05                205544.0                  44861.0
# 2022-01-06                 32085.0                    832.0
# ...                            ...                      ...
# 2023-11-28                 46376.0                  73360.0
# 2023-11-29                 18347.0                  20556.0
# 2023-11-30                 52723.0                  58230.0
# 2023-12-01                 11425.0                 231398.0
# 2023-12-02                 25370.0                  60564.0
#
#             MANAUSDT_PERP.A_longliq  MANAUSDT_PERP.A_shortliq  \
# 2022-01-02                  22516.0                   17497.0
# 2022-01-03                 145557.0                   11590.0
# 2022-01-04                 212523.0                    9730.0
# 2022-01-05                 653472.0                   88627.0
# 2022-01-06                 412973.0                  513847.0
# ...                             ...                       ...
# 2023-11-28                 431810.0                    2961.0
# 2023-11-29                  55680.0                    8172.0
# 2023-11-30                  51375.0                      86.0
# 2023-12-01                   2726.0                   12170.0
# 2023-12-02                   3906.0                   73641.0
#
#             HBARUSDT_PERP.A_longliq  HBARUSDT_PERP.A_shortliq  \
# 2022-01-02                  62358.0                   73906.0
# 2022-01-03                 341073.0                   36839.0
# 2022-01-04                 217191.0                  195997.0
# 2022-01-05                1822568.0                   98327.0
# 2022-01-06                 352089.0                   95069.0
# ...                             ...                       ...
# 2023-11-28                 276678.0                   40845.0
# 2023-11-29                 124723.0                    5313.0
# 2023-11-30                  37052.0                   71281.0
# 2023-12-01                  34777.0                    5409.0
# 2023-12-02                  91728.0                  112473.0
#
#             DYDXUSDT_PERP.A_longliq  DYDXUSDT_PERP.A_shortliq  \
# 2022-01-02                   1632.1                   10535.0
# 2022-01-03                  33328.0                       5.5
# 2022-01-04                  11749.7                     463.0
# 2022-01-05                 154618.6                   15609.7
# 2022-01-06                  25594.7                    2284.8
# ...                             ...                       ...
# 2023-11-28                 103745.7                   35993.5
# 2023-11-29                  19551.0                    9592.6
# 2023-11-30                  65989.3                   15724.2
# 2023-12-01                  33615.3                   20198.6
# 2023-12-02                  19583.4                   95043.2
#
#             COTIUSDT_PERP.A_longliq  COTIUSDT_PERP.A_shortliq
# 2022-01-02                  76885.0                   26845.0
# 2022-01-03                 143211.0                   26779.0
# 2022-01-04                 273429.0                  147684.0
# 2022-01-05                 818186.0                  104982.0
# 2022-01-06                 156865.0                   81615.0
# ...                             ...                       ...
# 2023-11-28                 118392.0                  392701.0
# 2023-11-29                 115362.0                  688066.0
# 2023-11-30                 405477.0                   12166.0
# 2023-12-01                   2448.0                   32477.0
# 2023-12-02                  39506.0                  108860.0
#
# [700 rows x 132 columns]

# %%
# Save the data in a csv to be used in the model building notebook
liq_all.to_csv('liquidations.csv')

# %% [markdown]
# ## Open Interest
#
# Open interest definition: total number of outstanding derivative contracts for an asset, such as options or futures, that have not been settled. Can provide accurate picture of a contract's liquidity and interest.
#
# From: https://www.investopedia.com

# %%
def get_symbol_oi(api_key, symbol = "BTCUSDT_PERP.A", threshold=700):
    
    url = 'https://api.coinalyze.net/v1/open-interest-history'
    params = {'api_key': api_key,"symbols": symbol,"interval":interval,"from":start,"to":end,
              #"convert_to_usd":'true',
              "history": [{"t": 0, # Unix Timestamp in seconds
                           "o": 0, # Open
                           "h": 0, # High
                           "l": 0, # Low
                           "c": 0  # Close
                          }]
             }
    
    response = requests.get(url, params=params)
    data = response.json()
    
    drop =['o','h','l']
    
    print(f"Symbol: {symbol}, Data Points: {len(data[0]['history'])}")

    if len(data[0]['history']) >= threshold:
        df = format_df(data,drop)
        df = df.rename(columns = {'c':'{}_oi'.format(data[0]['symbol'])})
    
        return df

# %%
oi_btc = get_symbol_oi(api_key)

oi_btc
# Out:
# Symbol: BTCUSDT_PERP.A, Data Points: 703
#             BTCUSDT_PERP.A_oi
# t
# 2022-01-02          73297.806
# 2022-01-03          79508.429
# 2022-01-04          81155.755
# 2022-01-05          77849.139
# 2022-01-06          79293.451
# ...                       ...
# 2023-12-01          89044.936
# 2023-12-02          81673.055
# 2023-12-03          79997.634
# 2023-12-04          83191.992
# 2023-12-05          84427.000
#
# [703 rows x 1 columns]

# %%
oi_all = get_all(get_symbol_oi,api_key)
# Out:
# Symbol: NMRUSDT_PERP.A, Data Points: 167
# Symbol: BIGTIMEUSDT_PERP.A, Data Points: 55
# Symbol: POWRUSDT_PERP.A, Data Points: 40
# Symbol: MAVUSDT_PERP.A, Data Points: 160
# Symbol: AGLDUSDT_PERP.A, Data Points: 130
# Symbol: CYBERUSDT_PERP.A, Data Points: 107
# Symbol: ARKUSDT_PERP.A, Data Points: 78
# Symbol: WLDUSDT_PERP.A, Data Points: 135
# Symbol: PENDLEUSDT_PERP.A, Data Points: 131
# Symbol: ARKMUSDT_PERP.A, Data Points: 131
# Symbol: FRONTUSDT_PERP.A, Data Points: 75
# Symbol: BONDUSDT_PERP.A, Data Points: 52
# Symbol: MDTUSDT_PERP.A, Data Points: 159
# Symbol: SEIUSDT_PERP.A, Data Points: 111
# Symbol: XVGUSDT_PERP.A, Data Points: 154
# Symbol: BNTUSDT_PERP.A, Data Points: 118
# Symbol: YGGUSDT_PERP.A, Data Points: 123
# Symbol: DODOXUSDT_PERP.A, Data Points: 120
# Symbol: OXTUSDT_PERP.A, Data Points: 117
# Symbol: MINAUSDT_PERP.A, Data Points: 303
# Symbol: PEOPLEUSDT_PERP.A, Data Points: 703
# Symbol: RIFUSDT_PERP.A, Data Points: 46
# Symbol: ASTRUSDT_PERP.A, Data Points: 295
# Symbol: XVSUSDT_PERP.A, Data Points: 237
# Symbol: MAGICUSDT_PERP.A, Data Points: 315
# Symbol: TUSDT_PERP.A, Data Points: 308
# Symbol: FETUSDT_PERP.A, Data Points: 323
# Symbol: HIGHUSDT_PERP.A, Data Points: 302
# Symbol: RNDRUSDT_PERP.A, Data Points: 306
# Symbol: FXSUSDT_PERP.A, Data Points: 320
# Symbol: CFXUSDT_PERP.A, Data Points: 289
# Symbol: IDEXUSDT_PERP.A, Data Points: 217
# Symbol: SNTUSDT_PERP.A, Data Points: 34
# Symbol: USDCUSDT_PERP.A, Data Points: 269
# Symbol: ETHWUSDT_PERP.A, Data Points: 8
# Symbol: SUIUSDT_PERP.A, Data Points: 217
# Symbol: OMGUSDT_PERP.A, Data Points: 703
# Symbol: BALUSDT_PERP.A, Data Points: 703
# Symbol: RENUSDT_PERP.A, Data Points: 703
# Symbol: STXUSDT_PERP.A, Data Points: 288
# Symbol: CRVUSDT_PERP.A, Data Points: 703
# Symbol: APEUSDT_PERP.A, Data Points: 629
# Symbol: STORJUSDT_PERP.A, Data Points: 703
# Symbol: RLCUSDT_PERP.A, Data Points: 703
# Symbol: SXPUSDT_PERP.A, Data Points: 703
# Symbol: KAVAUSDT_PERP.A, Data Points: 703
# Symbol: RSRUSDT_PERP.A, Data Points: 703
# Symbol: MTLUSDT_PERP.A, Data Points: 703
# Symbol: DOGEUSDT_PERP.A, Data Points: 703
# Symbol: BANDUSDT_PERP.A, Data Points: 703
# Symbol: WAVESUSDT_PERP.A, Data Points: 703
# Symbol: KSMUSDT_PERP.A, Data Points: 703
# Symbol: WOOUSDT_PERP.A, Data Points: 607
# Symbol: DUSKUSDT_PERP.A, Data Points: 698
# Symbol: AGIXUSDT_PERP.A, Data Points: 293
# Symbol: PHBUSDT_PERP.A, Data Points: 293
# Symbol: CAKEUSDT_PERP.A, Data Points: 34
# Symbol: FOOTBALLUSDT_PERP.A, Data Points: 461
# Symbol: JASMYUSDT_PERP.A, Data Points: 595
# Symbol: STRAXUSDT_PERP.A, Data Points: 56
# Symbol: ACHUSDT_PERP.A, Data Points: 287
# Symbol: BNXUSDT_PERP.A, Data Points: 603
# Symbol: ALGOUSDT_PERP.A, Data Points: 703
# Symbol: MATICUSDT_PERP.A, Data Points: 703
# Symbol: KNCUSDT_PERP.A, Data Points: 703
# Symbol: ZILUSDT_PERP.A, Data Points: 703
# Symbol: BLZUSDT_PERP.A, Data Points: 703
# Symbol: NEARUSDT_PERP.A, Data Points: 703
# Symbol: AVAXUSDT_PERP.A, Data Points: 703
# Symbol: MKRUSDT_PERP.A, Data Points: 703
# Symbol: SNXUSDT_PERP.A, Data Points: 703
# Symbol: ENJUSDT_PERP.A, Data Points: 703
# Symbol: ZRXUSDT_PERP.A, Data Points: 703
# Symbol: FLMUSDT_PERP.A, Data Points: 703
# Symbol: FTMUSDT_PERP.A, Data Points: 703
# Symbol: OPUSDT_PERP.A, Data Points: 553
# Symbol: UNIUSDT_PERP.A, Data Points: 703
# Symbol: SKLUSDT_PERP.A, Data Points: 703
# Symbol: TRBUSDT_PERP.A, Data Points: 703
# Symbol: TRXUSDT_PERP.A, Data Points: 703
# Symbol: BNBUSDT_PERP.A, Data Points: 703
# Symbol: XRPUSDT_PERP.A, Data Points: 703
# Symbol: NEOUSDT_PERP.A, Data Points: 703
# Symbol: EOSUSDT_PERP.A, Data Points: 703
# Symbol: ETCUSDT_PERP.A, Data Points: 703
# Symbol: BTCUSDT_PERP.A, Data Points: 703
# Symbol: LTCUSDT_PERP.A, Data Points: 703
# Symbol: XLMUSDT_PERP.A, Data Points: 703
# Symbol: LINKUSDT_PERP.A, Data Points: 703
# Symbol: ETHUSDT_PERP.A, Data Points: 703
# Symbol: BCHUSDT_PERP.A, Data Points: 703
# Symbol: ADAUSDT_PERP.A, Data Points: 703
# Symbol: XMRUSDT_PERP.A, Data Points: 703
# Symbol: DASHUSDT_PERP.A, Data Points: 703
# Symbol: ZECUSDT_PERP.A, Data Points: 703
# Symbol: ONTUSDT_PERP.A, Data Points: 703
# Symbol: ATOMUSDT_PERP.A, Data Points: 703
# Symbol: XTZUSDT_PERP.A, Data Points: 703
# Symbol: IOTAUSDT_PERP.A, Data Points: 703
# Symbol: BATUSDT_PERP.A, Data Points: 703
# Symbol: VETUSDT_PERP.A, Data Points: 703
# Symbol: QTUMUSDT_PERP.A, Data Points: 703
# Symbol: IOSTUSDT_PERP.A, Data Points: 703
# Symbol: THETAUSDT_PERP.A, Data Points: 703
# Symbol: AUDIOUSDT_PERP.A, Data Points: 703
# Symbol: SUSHIUSDT_PERP.A, Data Points: 703
# Symbol: COMPUSDT_PERP.A, Data Points: 703
# Symbol: RUNEUSDT_PERP.A, Data Points: 703
# Symbol: DOTUSDT_PERP.A, Data Points: 703
# Symbol: FILUSDT_PERP.A, Data Points: 703
# Symbol: AAVEUSDT_PERP.A, Data Points: 703
# Symbol: UNFIUSDT_PERP.A, Data Points: 703
# Symbol: GRTUSDT_PERP.A, Data Points: 703
# Symbol: DEFIUSDT_PERP.A, Data Points: 703
# Symbol: GTCUSDT_PERP.A, Data Points: 703
# Symbol: YFIUSDT_PERP.A, Data Points: 703
# Symbol: FLOWUSDT_PERP.A, Data Points: 664
# Symbol: LRCUSDT_PERP.A, Data Points: 703
# Symbol: SOLUSDT_PERP.A, Data Points: 703
# Symbol: EGLDUSDT_PERP.A, Data Points: 703
# Symbol: ICXUSDT_PERP.A, Data Points: 703
# Symbol: IMXUSDT_PERP.A, Data Points: 663
# Symbol: OCEANUSDT_PERP.A, Data Points: 703
# Symbol: ROSEUSDT_PERP.A, Data Points: 703
# Symbol: CKBUSDT_PERP.A, Data Points: 281
# Symbol: OGNUSDT_PERP.A, Data Points: 703
# Symbol: BELUSDT_PERP.A, Data Points: 703
# Symbol: CTKUSDT_PERP.A, Data Points: 703
# Symbol: AXSUSDT_PERP.A, Data Points: 703
# Symbol: SPELLUSDT_PERP.A, Data Points: 456
# Symbol: MASKUSDT_PERP.A, Data Points: 703
# Symbol: ALPHAUSDT_PERP.A, Data Points: 703
# Symbol: ZENUSDT_PERP.A, Data Points: 703
# Symbol: ORBSUSDT_PERP.A, Data Points: 50
# Symbol: LDOUSDT_PERP.A, Data Points: 440
# Symbol: BAKEUSDT_PERP.A, Data Points: 703
# Symbol: CVXUSDT_PERP.A, Data Points: 440
# Symbol: 1INCHUSDT_PERP.A, Data Points: 703
# Symbol: LINAUSDT_PERP.A, Data Points: 703
# Symbol: TRUUSDT_PERP.A, Data Points: 274
# Symbol: CELOUSDT_PERP.A, Data Points: 703
# Symbol: 1000LUNCUSDT_PERP.A, Data Points: 453
# Symbol: GALAUSDT_PERP.A, Data Points: 703
# Symbol: PERPUSDT_PERP.A, Data Points: 275
# Symbol: CELRUSDT_PERP.A, Data Points: 703
# Symbol: GMXUSDT_PERP.A, Data Points: 292
# Symbol: 1000PEPEUSDT_PERP.A, Data Points: 215
# Symbol: DGBUSDT_PERP.A, Data Points: 703
# Symbol: REEFUSDT_PERP.A, Data Points: 703
# Symbol: ANKRUSDT_PERP.A, Data Points: 703
# Symbol: CHZUSDT_PERP.A, Data Points: 703
# Symbol: LPTUSDT_PERP.A, Data Points: 703
# Symbol: BLURUSDT_PERP.A, Data Points: 222
# Symbol: ALICEUSDT_PERP.A, Data Points: 703
# Symbol: 1000SHIBUSDT_PERP.A, Data Points: 703
# Symbol: SANDUSDT_PERP.A, Data Points: 703
# Symbol: RVNUSDT_PERP.A, Data Points: 703
# Symbol: GMTUSDT_PERP.A, Data Points: 631
# Symbol: EDUUSDT_PERP.A, Data Points: 220
# Symbol: SFPUSDT_PERP.A, Data Points: 703
# Symbol: LITUSDT_PERP.A, Data Points: 703
# Symbol: IDUSDT_PERP.A, Data Points: 258
# Symbol: XEMUSDT_PERP.A, Data Points: 703
# Symbol: ATAUSDT_PERP.A, Data Points: 703
# Symbol: HOTUSDT_PERP.A, Data Points: 703
# Symbol: STMXUSDT_PERP.A, Data Points: 703
# Symbol: C98USDT_PERP.A, Data Points: 703
# Symbol: ARUSDT_PERP.A, Data Points: 703
# Symbol: MANAUSDT_PERP.A, Data Points: 703
# Symbol: ONEUSDT_PERP.A, Data Points: 703
# Symbol: HBARUSDT_PERP.A, Data Points: 703
# Symbol: CHRUSDT_PERP.A, Data Points: 703
# Symbol: ARBUSDT_PERP.A, Data Points: 258
# Symbol: DYDXUSDT_PERP.A, Data Points: 703
# Symbol: SSVUSDT_PERP.A, Data Points: 285
# Symbol: KEYUSDT_PERP.A, Data Points: 196
# Symbol: COTIUSDT_PERP.A, Data Points: 703
# Symbol: DENTUSDT_PERP.A, Data Points: 703
# Symbol: COMBOUSDT_PERP.A, Data Points: 187
# Symbol: NKNUSDT_PERP.A, Data Points: 703
# Symbol: IOTXUSDT_PERP.A, Data Points: 703
# Symbol: CTSIUSDT_PERP.A, Data Points: 703
# Symbol: 1000XECUSDT_PERP.A, Data Points: 703
# Symbol: ENSUSDT_PERP.A, Data Points: 703
# Symbol: STPTUSDT_PERP.A, Data Points: 49
# Symbol: LQTYUSDT_PERP.A, Data Points: 271
# Symbol: KLAYUSDT_PERP.A, Data Points: 703
# Symbol: ARPAUSDT_PERP.A, Data Points: 703
# Symbol: JOEUSDT_PERP.A, Data Points: 252
# Symbol: WAXPUSDT_PERP.A, Data Points: 49
# Symbol: LOOMUSDT_PERP.A, Data Points: 56
# Symbol: RDNTUSDT_PERP.A, Data Points: 245
# Symbol: NTRNUSDT_PERP.A, Data Points: 22
# Symbol: LUNA2USDT_PERP.A, Data Points: 452
# Symbol: HFTUSDT_PERP.A, Data Points: 244
# Symbol: AMBUSDT_PERP.A, Data Points: 251
# Symbol: LEVERUSDT_PERP.A, Data Points: 251
# Symbol: TLMUSDT_PERP.A, Data Points: 410
# Symbol: HOOKUSDT_PERP.A, Data Points: 317
# Symbol: QNTUSDT_PERP.A, Data Points: 412
# Symbol: ANTUSDT_PERP.A, Data Points: 703
# Symbol: API3USDT_PERP.A, Data Points: 652
# Symbol: STGUSDT_PERP.A, Data Points: 468
# Symbol: INJUSDT_PERP.A, Data Points: 476
# Symbol: MBLUSDT_PERP.A, Data Points: 22
# Symbol: GALUSDT_PERP.A, Data Points: 580
# Symbol: APTUSDT_PERP.A, Data Points: 413
# Symbol: RADUSDT_PERP.A, Data Points: 210
# Symbol: UMAUSDT_PERP.A, Data Points: 210
# Symbol: BLUEBIRDUSDT_PERP.A, Data Points: 399
# Symbol: DARUSDT_PERP.A, Data Points: 586
# Symbol: ICPUSDT_PERP.A, Data Points: 595
# Symbol: KASUSDT_PERP.A, Data Points: 19
# Symbol: MEMEUSDT_PERP.A, Data Points: 33
# Symbol: HIFIUSDT_PERP.A, Data Points: 81
# Symbol: GLMRUSDT_PERP.A, Data Points: 71
# Symbol: BICOUSDT_PERP.A, Data Points: 69
# Symbol: TWTUSDT_PERP.A, Data Points: 33
# Symbol: TOKENUSDT_PERP.A, Data Points: 33
# Symbol: BSVUSDT_PERP.A, Data Points: 47
# Symbol: POLYXUSDT_PERP.A, Data Points: 42
# Symbol: GASUSDT_PERP.A, Data Points: 42
# Symbol: SLPUSDT_PERP.A, Data Points: 36
# Symbol: TIAUSDT_PERP.A, Data Points: 36
# Symbol: ORDIUSDT_PERP.A, Data Points: 29
# Symbol: STEEMUSDT_PERP.A, Data Points: 28
# Symbol: BADGERUSDT_PERP.A, Data Points: 27
# Symbol: ILVUSDT_PERP.A, Data Points: 26
# Symbol: SUPERUSDT_PERP.A, Data Points: 10
# Symbol: USTCUSDT_PERP.A, Data Points: 9
# Symbol: ONGUSDT_PERP.A, Data Points: 9
# Symbol: BEAMXUSDT_PERP.A, Data Points: 14
# Symbol: 1000BONKUSDT_PERP.A, Data Points: 14
# Symbol: PYTHUSDT_PERP.A, Data Points: 14

# %%
# Save the data in a csv to be used in the model building notebook
oi_all.to_csv('open interest.csv')

# %% [markdown]
# ## Funding Rate
# Funding rate definition: represents the difference between the mark price of the futures market and the index price, equivalent to the spot market. A positive funding rate means users with long positions pay a funding fee to those with short positions, and vice versa for negative funding rate.
#
# From: https://help.coinbase.com/en

# %%
def get_symbol_funding_rate(api_key, symbol='BTCUSDT_PERP.A', threshold=700):
    
    url = 'https://api.coinalyze.net/v1/funding-rate-history'
    params = {'api_key': api_key,"symbols": symbol,"interval":interval,"from":start,"to":end,
              "history": [{"t": 0, # Unix Timestamp in seconds
                           "o": 0, # Open
                           "h": 0, # High
                           "l": 0, # Low
                           "c": 0  # Close
                          }]
             }
    
    response = requests.get(url, params=params)
    data = response.json()
    
    drop =['o','h','l']
    
    #print(f"Symbol: {symbol}, Data Points: {len(data[0]['history'])}")

    if len(data[0]['history']) >= threshold:
        df = format_df(data,drop)
        df = df.rename(columns = {'c':'{}_fr'.format(data[0]['symbol'])})
    
        return df

# %%
fr_btc = get_symbol_funding_rate(api_key)

fr_btc
# Out:
#             BTCUSDT_PERP.A_fr
# t
# 2022-01-02           0.010000
# 2022-01-03           0.010000
# 2022-01-04           0.010000
# 2022-01-05           0.010000
# 2022-01-06           0.010000
# ...                       ...
# 2023-12-01           0.010000
# 2023-12-02           0.008541
# 2023-12-03           0.010000
# 2023-12-04           0.010000
# 2023-12-05           0.010000
#
# [703 rows x 1 columns]

# %%
fr_all = get_all(get_symbol_funding_rate,api_key)

# %%
fr_all
# Out:
#             PEOPLEUSDT_PERP.A_fr  OMGUSDT_PERP.A_fr  BALUSDT_PERP.A_fr  \
# t
# 2022-01-02              0.010000           0.010000           0.010000
# 2022-01-03              0.010000           0.010000           0.010000
# 2022-01-04              0.010000           0.010000           0.010000
# 2022-01-05              0.010000           0.010000           0.010000
# 2022-01-06              0.010000           0.010000          -0.075603
# ...                          ...                ...                ...
# 2023-12-01              0.010000           0.010000           0.010000
# 2023-12-02              0.011709           0.010000           0.010000
# 2023-12-03              0.019545           0.010000           0.010000
# 2023-12-04              0.020599           0.019837           0.010000
# 2023-12-05              0.010000           0.022059           0.010000
#
#             RENUSDT_PERP.A_fr  CRVUSDT_PERP.A_fr  STORJUSDT_PERP.A_fr  \
# t
# 2022-01-02           0.010000            0.01000            -0.019553
# 2022-01-03           0.010000            0.01000             0.010000
# 2022-01-04           0.010000            0.01000             0.010000
# 2022-01-05           0.010000            0.01000             0.010000
# 2022-01-06           0.010000            0.01000             0.007112
# ...                       ...                ...                  ...
# 2023-12-01           0.010000            0.01000             0.010000
# 2023-12-02           0.013913            0.01000             0.020603
# 2023-12-03           0.010000            0.01000             0.021040
# 2023-12-04           0.010000            0.02269             0.010000
# 2023-12-05           0.013626            0.01000             0.010000
#
#             RLCUSDT_PERP.A_fr  SXPUSDT_PERP.A_fr  KAVAUSDT_PERP.A_fr  \
# t
# 2022-01-02           0.010000           0.010000                0.01
# 2022-01-03           0.010000           0.010000                0.01
# 2022-01-04           0.010000           0.010000                0.01
# 2022-01-05           0.010000           0.010000                0.01
# 2022-01-06           0.008475           0.010000                0.01
# ...                       ...                ...                 ...
# 2023-12-01           0.010000           0.010000                0.01
# 2023-12-02           0.010000           0.010000                0.01
# 2023-12-03           0.019361           0.017163                0.01
# 2023-12-04           0.010000           0.010000                0.01
# 2023-12-05           0.010000           0.012645                0.01
#
#             RSRUSDT_PERP.A_fr  ...  COTIUSDT_PERP.A_fr  DENTUSDT_PERP.A_fr  \
# t                              ...
# 2022-01-02               0.01  ...             0.01000            0.010000
# 2022-01-03               0.01  ...             0.01000            0.010000
# 2022-01-04               0.01  ...             0.01000            0.010000
# 2022-01-05               0.01  ...             0.01000            0.010000
# 2022-01-06               0.01  ...             0.01000            0.010000
# ...                       ...  ...                 ...                 ...
# 2023-12-01               0.01  ...             0.00716            0.010000
# 2023-12-02               0.01  ...             0.01000            0.022164
# 2023-12-03               0.01  ...             0.01000            0.015805
# 2023-12-04               0.01  ...             0.01000            0.015978
# 2023-12-05               0.01  ...             0.01000            0.017188
#
#             NKNUSDT_PERP.A_fr  IOTXUSDT_PERP.A_fr  CTSIUSDT_PERP.A_fr  \
# t
# 2022-01-02           0.010000            0.010000            0.010000
# 2022-01-03           0.010000            0.010000            0.010000
# 2022-01-04           0.010000            0.010000            0.010000
# 2022-01-05           0.010000            0.010000            0.010000
# 2022-01-06          -0.040119            0.010000            0.010000
# ...                       ...                 ...                 ...
# 2023-12-01           0.010000            0.010000            0.010000
# 2023-12-02           0.022252            0.015485            0.010000
# 2023-12-03           0.010000            0.010000            0.010000
# 2023-12-04           0.028447            0.010000            0.022216
# 2023-12-05           0.029720           -0.198026            0.010000
#
#             1000XECUSDT_PERP.A_fr  ENSUSDT_PERP.A_fr  KLAYUSDT_PERP.A_fr  \
# t
# 2022-01-02              -0.085688           0.010000            0.010000
# 2022-01-03               0.008957           0.010000            0.010000
# 2022-01-04              -0.049702           0.010000            0.010000
# 2022-01-05              -0.108208           0.010000            0.010000
# 2022-01-06               0.004942           0.010000            0.010000
# ...                           ...                ...                 ...
# 2023-12-01               0.010000           0.010000            0.010000
# 2023-12-02               0.010000           0.023625            0.010000
# 2023-12-03               0.010000           0.023881            0.010000
# 2023-12-04               0.010107           0.017057            0.010000
# 2023-12-05               0.010000           0.010589            0.024136
#
#             ARPAUSDT_PERP.A_fr  ANTUSDT_PERP.A_fr
# t
# 2022-01-02            0.010000           0.010000
# 2022-01-03            0.010000           0.010000
# 2022-01-04            0.010000           0.010000
# 2022-01-05            0.010000           0.010000
# 2022-01-06            0.002022           0.010000
# ...                        ...                ...
# 2023-12-01            0.010000           0.010000
# 2023-12-02            0.010000           0.010000
# 2023-12-03            0.010000           0.010000
# 2023-12-04            0.010000           0.010000
# 2023-12-05            0.028185           0.029008
#
# [703 rows x 119 columns]

# %%
# Save the data in a csv to be used in the model building notebook
fr_all.to_csv('funding rate.csv')

# %% [markdown]
# ## Older Bitcoin Close Data
# Extracting older Bitcoin data close will facilitate the calculation of the Simple Moving Average for a window of 200 days.

# %%
# Define an older time horizon
older = int(time.mktime(time.strptime('2019-01-01 00:00:00', '%Y-%m-%d %H:%M:%S')))

# %%
def get_symbol_old_close(api_key, symbol='BTCUSDT_PERP.A'):
    
    url = 'https://api.coinalyze.net/v1/ohlcv-history'
    
    params = {'api_key': api_key,"symbols": symbol,"interval":interval,"from":older,"to":end,
              "history": [{
                  "t": 0,   # Unix Timestamp in seconds
                  "o": 0,   # Open
                  "h": 0,   # High
                  "l": 0,   # Low
                  "c": 0,   # Close
                  "v": 0,   # Volume
                  "bv": 0,  # Base Volume
                  "tx": 0,  # Total trades
                  "btx": 0  # Buy Trades
              }]
             }
    
    # Perform the JSON request with the URL and parameters
    response = requests.get(url, params=params)
    data = response.json()
    
    # Columns to drop (see column names above)
    drop = ['o', 'h', 'l', 'v', 'bv', 'tx', 'btx']
    
    #print(f"Symbol: {symbol}, Data Points: {len(data[0]['history'])}")
    
    # Estalish a threshold limit of minimum days in analysis periods with data

    df = format_df(data, drop)
    df.rename(columns={'c': f"{data[0]['symbol']}_close"}, inplace=True)
        
    return df

# %%
# Create dataframe containing only the older Bitcoin close data
close_volume_older_btc = get_symbol_old_close(api_key)

# View the dataframe
close_volume_older_btc.head()
# Out:
#             BTCUSDT_PERP.A_close
# t
# 2019-09-12              10415.13
# 2019-09-13              10341.34
# 2019-09-14              10332.25
# 2019-09-15              10302.22
# 2019-09-16              10249.27

# %%
# Save the data in a csv to be used in the model building notebook
close_volume_older_btc.to_csv('older btc closes.csv')
